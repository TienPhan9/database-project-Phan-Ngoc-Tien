# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('/content/sample_data/InfomationRestaurants.csv', encoding='utf-8')

# %%
df.head(3)
# Out:
#            name                                            address  \
# 0         Kabin  8-15 Ton Duc Thang Street, District 1 Renaissa...
# 1    The Lounge  88 Đồng Khởi, Q.1 Khách Sạn Sheraton, Thành ph...
# 2  Việt Kitchen  8-15 Tôn Đức Thắng Khách Sạn Renaissance River...
#
#               phone                                           timeOpen  \
# 0  +84 28 3822 0033  Đang mở cửa: 11:30 SA - 2:30 CH6:00 CH - 10:00 CH
# 1  +84 28 3827 2828                   Đang mở cửa: 07:00 SA - 12:00 SA
# 2  +84 28 3822 0033                   Đang mở cửa: 06:00 SA - 10:00 CH
#
#   ratingAverage               priceRange  \
# 0           5,0  380.952 ₫ - 2.380.952 ₫
# 1           5,0        Quầy bar, Cà phê
# 2           5,0  309.524 ₫ - 2.380.952 ₫
#
#                                              details
# 0  380.952 ₫ - 2.380.952 ₫, Kiểu Trung Quốc, Phù ...
# 1  Quầy bar, Cà phê, Phù hợp với người ăn chay, ...
# 2  309.524 ₫ - 2.380.952 ₫, Quốc tế, Hải sản,...

# %%
word_counts = Counter(df['details'].str.cat(sep=', ').split(', '))
print(word_counts)
# Out:
# Counter({'Bữa tối': 1598, 'Bữa trưa': 1343, 'Kiểu Việt': 985, 'Kiểu Á': 894, 'Đồ uống': 732, 'Phù hợp với người ăn chay': 619, 'Bữa sáng': 521, 'Chỗ ngồi': 476, 'Đêm muộn': 434, 'Tùy chọn ăn chay': 430, 'Đặt chỗ': 423, 'Bữa nửa buổi': 417, 'Quán rượu': 384, 'Quầy bar': 374, 'Dịch vụ bàn': 354, 'Kiểu Nhật': 314, 'Phục vụ đồ uống có cồn': 269, 'Cà phê': 263, 'Kiểu Âu': 243, 'Wifi miễn phí': 236, 'Hải sản': 230, 'Tùy chọn đồ ăn không có gluten': 220, 'Chấp nhận thẻ tín dụng': 204, 'Quốc tế': 200, 'Món kết hợp': 190, 'Cửa hàng bán thức ăn mang về': 179, 'Kiểu Pháp': 168, 'Đồ nướng': 167, 'Rượu và bia': 165, 'Có bãi đỗ xe': 160, 'Tốt cho sức khỏe': 155, 'Kiểu Mỹ': 152, 'Kiểu Ý': 152, 'Thịt nướng': 140, 'Kiểu Trung Quốc': 136, 'Quầy bar đầy đủ': 135, 'Quầy rượu vang': 126, 'Nhà hàng bít tết': 124, 'Thanh toán điện tử': 122, 'Ngồi ngoài trời': 119, 'Cửa hàng thức ăn ngon': 119, 'Kiểu Bữa tối': 115, 'Quán bar phục vụ đồ ăn': 112, 'Kiểu 
# ...

# %%
print(word_counts)
# Out:
# Counter({'Bữa': 3383, 'Kiểu': 3336, 'ăn': 1759, '₫': 1306, '-': 1303, '₫,': 1300, 'trưa,': 1254, 'tối,': 1145, 'Á,': 881, 'Việt,': 861, 'chay,': 789, 'vụ': 744, 'uống': 742, 'Đồ': 734, 'Tùy': 650, 'chọn': 650, 'Bữa': 636, 'Quầy': 635, 'Phù': 619, 'hợp': 619, 'với': 619, 'người': 619, 'đồ': 607, 'nhận': 509, 'có': 508, 'thẻ': 504, 'sáng,': 498, 'Kiểu': 491, 'Chỗ': 476, 'Chấp': 467, 'tối': 453, 'Đêm': 434, 'Đặt': 423, 'nửa': 417, 'Quán': 414, 'ngồi,': 412, 'hàng': 396, 'muộn,': 389, 'rượu,': 377, 'bar,': 374, 'Dịch': 357, 'buổi,': 341, 'chỗ,': 335, 'bia,': 317, 'đỗ': 314, 'nướng,': 305, 'miễn': 300, 'bar': 292, 'Nhật,': 285, 'Phục': 269, 'bán': 269, 'phí,': 267, 'Cà': 263, 'uống,': 261, 'chay': 260, 'không': 257, 'cho': 256, 'cồn,': 255, 'phê,': 254, 'Âu,': 253, 'xe': 253, 'sản,': 250, 'Có': 245, 'Đồ': 240, 'Wifi': 236, 'Hải': 230, 'Trung': 229, 'hàng': 224, 'Nhà': 214, 'Quốc': 211, 'bàn': 210, 'Thịt': 206, 'tín': 204, 'tế,': 198, 'Món': 190, 'kết': 190, 'Quá
# ...
